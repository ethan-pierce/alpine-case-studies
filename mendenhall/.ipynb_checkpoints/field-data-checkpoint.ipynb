# 25           8.80         0.042304  0.70
# 26          55.20         0.188467  1.45
# 27           1.80         0.007733  1.65
# 28           0.57         0.002425  1.95
# 29           6.59         0.029217  0.35
# 30           6.85         0.032638  0.65
# 31           2.93         0.011159  1.10
# 32           3.64         0.016577  1.40
# 33           6.24         0.031866  0.35
# 34           2.66         0.013114  0.70
# 35           2.98         0.011824  1.10
# 36           3.99         0.018330  1.50

# %%
ssc['Site'] = [int(str(i)[0]) for i in ssc['Sample number']]
ssc['Sample'] = [int(str(i)[2]) for i in ssc['Sample number']]

ssc
# Out:
#     Field tag  Sample number  Total mass  Empty mass  Sediment + water mass  \
# 0       27280            1.1      271.71       57.84                 213.87
# 1       27281            1.2      273.53       57.38                 216.15
# 2       27282            1.3      276.55       56.09                 220.46
# 3       27283            1.4      294.31       57.82                 236.49
# 4       27284            1.5      163.33       57.57                 105.76
# 5       27285            1.6      250.24       57.41                 192.83
# 6       27286            1.7      269.30       57.44                 211.86
# 7       27287            1.8      321.80       57.30                 264.50
# 8       27288            2.1      250.03       57.22                 192.81
# 9       27289            2.2      199.87       57.60                 142.27
# 10      27290            2.3      238.05       57.48                 180.57
# 11      27291            2.4      219.09       57.48                 161.61
# 12      27292            2.5      232.30       57.60                 174.70
# 13      27293            2.6      229.06       58.11                 170.95
# 14      27294            2.7      233.72       57.53                 176.19
# 15      27295            3.1      309.54       56.15                 253.39
# 16      27296            3.2      320.69       56.58                 264.11
# 17      27297            3.3      270.36       57.41                 212.95
# 18      27298            3.4      257.97       57.14                 200.83
# 19      27299            3.5      193.76       56.66                 137.10
# 20      27300            3.6      241.54       57.46                 184.08
# 21      27301            3.7      325.55       57.25                 268.30
# 22      27302            4.1      247.49       57.48                 190.01
# 23      27303            4.2      268.04       57.63                 210.41
# 24      27304            4.3      310.61       57.48                 253.13
# 25      27305            4.4      265.52       57.50                 208.02
# 26      27306            4.5      350.31       57.42                 292.89
# 27      27307            4.6      290.12       57.36                 232.76
# 28      27308            4.7      292.62       57.60                 235.02
# 29      27309            5.1      283.38       57.83                 225.55
# 30      27310            5.2      266.20       56.32                 209.88
# 31      27311            5.3      319.88       57.32                 262.56
# 32      27312            5.4      275.84       56.26                 219.58
# 33      27313            5.5      253.56       57.74                 195.82
# 34      27314            5.6      260.23       57.40                 202.83
# 35      27315            5.7      309.46       57.42                 252.04
# 36      27316            5.8      275.18       57.50                 217.68
#
#     Sediment mass  Sediment mass %     z  Site  Sample
# 0            8.56         0.040024  0.30     1       1
# 1            3.34         0.015452  0.57     1       2
# 2            0.58         0.002631  1.02     1       3
# 3            0.09         0.000381  1.95     1       4
# 4            4.48         0.042360  0.24     1       5
# 5            0.65         0.003371  0.44     1       6
# 6            1.08         0.005098  1.36     1       7
# 7            0.06         0.000227  1.75     1       8
# 8           53.04         0.275089  0.33     2       1
# 9            0.55         0.003866  0.88     2       2
# 10           4.18         0.023149  1.45     2       3
# 11           0.35         0.002166  1.70     2       4
# 12          32.86         0.188094  0.54     2       5
# 13           0.97         0.005674  0.97     2       6
# 14           7.36         0.041773  1.27     2       7
# 15           1.76         0.006946  0.18     3       1
# 16           1.24         0.004695  0.95     3       2
# 17          10.42         0.048932  1.52     3       3
# 18           0.54         0.002689  1.85     3       4
# 19          28.91         0.210868  0.49     3       5
# 20           3.71         0.020154  1.12     3       6
# 21           0.88         0.003280  1.75     3       7
# 22           3.74         0.019683  0.55     4       1
# 23          29.27         0.139109  1.30     4       2
# 24           1.90         0.007506  1.65     4       3
# 25           8.80         0.042304  0.70     4       4
# 26          55.20         0.188467  1.45     4       5
# 27           1.80         0.007733  1.65     4       6
# 28           0.57         0.002425  1.95     4       7
# 29           6.59         0.029217  0.35     5       1
# 30           6.85         0.032638  0.65     5       2
# 31           2.93         0.011159  1.10     5       3
# 32           3.64         0.016577  1.40     5       4
# 33           6.24         0.031866  0.35     5       5
# 34           2.66         0.013114  0.70     5       6
# 35           2.98         0.011824  1.10     5       7
# 36           3.99         0.018330  1.50     5       8

# %%
plt.style.use('default')

# %%
plt.rcParams['font.size'] = 12

# %%
for i in range(5):
    j = i + 1
    fig, ax = plt.subplots(1, 2, figsize = (4, 8))
    
    for idx, row in ssc[ssc['Site'] == j].iterrows():
        if row.Sample in [1.0, 2.0, 3.0, 4.0]:
            ax[0].scatter(row['Sediment mass %'] * 100, row['z'], color = 'blue', s = 80)
        else:
            ax[1].scatter(row['Sediment mass %'] * 100, row['z'], color = 'blue', s = 80)
            
    ax[0].set_title('Column ' + str(j) + 'a')
    ax[1].set_title('Column ' + str(j) + 'b')
    
    ax[0].set_xlabel('SSC (mass %)')
    ax[1].set_xlabel('SSC (mass %)')
    ax[0].set_ylabel('Height (m)')
    ax[1].set_ylabel('Height (m)')
    
    plt.tight_layout()
    plt.show()

# %%
plt.style.use('fivethirtyeight')

fig, axes = plt.subplots(1, 5, figsize = (15, 8))

for i in range(5):
    j = i + 1
    
    ax = axes[j - 1]
    
    for idx, row in ssc[ssc['Site'] == j].iterrows():
        ax.scatter(row['Sediment mass %'] * 100, row['z'], color = 'blue', s = 80)
            
    ax.set_title('Column ' + str(j))

    ax.set_xlabel('SSC (mass %)')
    ax.set_ylabel('Height (m)')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (2, 8))

for idx, row in ssc.iterrows():
    ax.scatter(row['Sediment mass %'], row['z'], s = 80)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (2, 8))

for idx, row in ssc.iterrows():
    if not (row['Sediment mass %'] > 0.1) & (row['z'] > 0.5):
        ax.scatter(row['Sediment mass %'], row['z'], s = 80)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (2, 8))

for idx, row in ssc.iterrows():
    if not (row['Sediment mass %'] > 0.1):
        ax.scatter(row['Sediment mass %'], row['z'], s = 80)

plt.show()
